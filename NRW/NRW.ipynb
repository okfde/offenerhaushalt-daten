# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/Michael/Documents/GitHub/offenerhaushalt-pipeline/schleswig-holstein/haushalt-schleswig-holstein-enriched.csv',  sep=',', encoding='utf-8')

# %%
df.dtypes
# Out:
# Kapitel             int64
# Titel               int64
# FKZ                 int64
# Zweckbestimmung    object
# Gruppe 3           object
# Gruppe 2           object
# Gruppe 1           object
# Funktion 3         object
# Funktion 2         object
# Funktion 1         object
# Einzelplan_Name    object
# Kapitel_Name       object
# Jahr                int64
# Wert                int64
# Art                object
# dtype: object

# %%
#df.Wert = df.Wert.astype(str)

# %%
#df.Wert = df.Wert.astype(float)

# %%
#df[:5]

# %%
#df['Wert'] = df['Wert'].str.replace(',','.')

# %%
#df[:55]

# %%
#df['Wert'] = df['Wert'].str.replace('.','')

# %%
#df['Wert'] = pd.to_numeric(df['Wert'])

# %%
#df[:50]

# %%
liste = {'Einnahme': 'Einnahme', 
        'Ausabe': 'Ausgabe'}

# %%
teil = df['Art']

# %%
df['Art'] = [liste[i] for i in teil.values]

# %%
df[:100]
# Out:
#     Kapitel  Titel  FKZ                                    Zweckbestimmung  \
# 0       101  11901   11                   Einnahmen aus Veröffentlichungen
# 1       101  11901   11                   Einnahmen aus Veröffentlichungen
# 2       101  11901   11                   Einnahmen aus Veröffentlichungen
# 3       101  11902   11  Kostenbeiträge für private Benutzung verwaltun...
# 4       101  11902   11  Kostenbeiträge für private Benutzung verwaltun...
# 5       101  11902   11  Kostenbeiträge für private Benutzung verwaltun...
# 6       101  11903   11  Einnahmen aus dem Verkauf von Katalogen usw. b...
# 7       101  11903   11  Einnahmen aus dem Verkauf von Katalogen usw. b...
# 8       101  11903   11  Einnahmen aus dem Verkauf von Katalogen usw. b...
# 9       101  11904   11  Erlöse aus dem Verkauf unbrauchbarer oder entb...
# 10      101  11904   11  Erlöse aus dem Verkauf unbrauchbarer oder entb...
# ...

# %%
df.to_csv('C:/Users/Michael/Documents/GitHub/offenerhaushalt-pipeline/schleswig-holstein/haushalt-schleswig-holstein-enriched.csv', index=False, encoding='utf-8')
